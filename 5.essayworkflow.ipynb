# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict,Annotated
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from pydantic import BaseModel,Field
import operator

# %%
load_dotenv()
# Out:
# True

# %%
model=ChatOpenAI(model='gpt-5.6-luna')

# %%
class EvaluationSchema(BaseModel):
    feedback: str=Field(description='Detailed Feedback for the essay')
    score: int=Field(description='Score out of 10',ge=0,le=10)

# %%
structured_model=model.with_structured_output(EvaluationSchema)

# %%
essay='''"""Europe in the Age of AI: The Regulatory Superpower

As the world rushes headlong into the era of artificial intelligence, the European Union finds itself playing a unique and complex role. While the United States and China dominate the race to build the largest foundation models and hardware ecosystems, Europe has positioned itself as the global conscience of the AI age. For Europe, the challenge is not simply about technological supremacy, but about ensuring that AI aligns with democratic values, human rights, and environmental sustainability.

Europe's strengths lie in its deep academic traditions and its commitment to ethical frameworks. The continent is home to world-class research hubs, producing some of the leading minds in machine learning. Furthermore, Europe has a distinct advantage in industrial and B2B AI, driven by its manufacturing powerhouses in Germany, France, and Scandinavia. However, Europe’s most defining characteristic in this era is its regulatory muscle. With the passage of the AI Act, the EU has created the world’s first comprehensive legal framework for artificial intelligence, categorizing systems by risk and demanding unprecedented transparency from tech companies.

The European vision for AI is heavily focused on public good and sustainability. There is a strong push toward "Green AI," ensuring that the massive energy consumption of data centers aligns with the continent's aggressive climate goals. In healthcare, European nations are leveraging AI to advance precision medicine and streamline public health systems, while fiercely protecting patient data. Additionally, significant investments are being made to develop open-source, multilingual AI models that preserve Europe's rich linguistic diversity and reduce reliance on Silicon Valley.

Despite these noble ambitions, Europe faces substantial hurdles. The continent suffers from a severe lack of hyperscale tech companies and domestic cloud infrastructure, leaving it heavily dependent on foreign technology. This "compute deficit" is compounded by a fragmented venture capital market, which often struggles to commercialize academic breakthroughs. Consequently, Europe frequently experiences a brain drain, as its brightest AI researchers are lured away by the massive salaries and computing resources offered by American and Chinese tech giants.

The central tension for Europe is whether its regulatory approach will foster "trustworthy AI" or stifle homegrown innovation. Critics argue that stringent compliance burdens will price European startups out of the market, relegating the continent to being a consumer of foreign AI rather than a creator. Proponents, however, believe that by setting global ethical standards—the "Brussels Effect"—Europe will ultimately attract users and enterprises that demand secure, unbiased, and privacy-respecting technologies.

To succeed, Europe must balance its protective instincts with aggressive investment in digital infrastructure and innovation. It needs to foster a unified digital single market that allows startups to scale across borders effortlessly, while also forging strategic alliances to secure supply chains for critical hardware like semiconductors.

In conclusion, Europe in the age of AI represents a profound geopolitical experiment. It is testing whether a society can successfully govern exponential technology without sacrificing economic competitiveness. If Europe succeeds, it will provide a desperately needed global blueprint for human-centric AI; if it fails, it risks becoming an over-regulated museum in a world driven by algorithmic innovation."""'''

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}'
result=structured_model.invoke(prompt)

# %%
result
# Out:
# EvaluationSchema(feedback='The essay demonstrates a high level of language quality. It is coherent, well organized, and written in a confident, professional style. The introduction establishes the central argument effectively, while the body paragraphs develop Europe’s strengths, ambitions, obstacles, and strategic choices in a logical sequence. The conclusion returns to the main theme and ends with a memorable contrast between Europe as a “global blueprint” and an “over-regulated museum.” Word choice is generally precise and sophisticated, with effective terms such as “regulatory muscle,” “compute deficit,” “brain drain,” and “Brussels Effect.” Sentence structure is varied, and transitions such as “Furthermore,” “Despite these noble ambitions,” “Consequently,” and “In conclusion” help maintain cohesion.\n\nThe main weakness is that the prose occasionally becomes overly rhetorical or generalized. Phrases such as “playing a unique and complex role,” “global conscience of the AI age,” “deep academic traditions,” and “fiercely protecting patient data” are persuasive but somewhat broad and would benefit from more precise qualification or supporting examples. Some metaphors—“rushes headlong,” “regulatory muscle,” and “over-regulated museum”—give the essay energy, but their frequent use slightly shifts the tone from analytical to editorial. The claim that the AI Act is the “world’s first comprehensive legal framework” may also require careful qualification, since the essay would be stronger if it distinguished between comprehensive regulation and earlier sector-specific or national AI rules.\n\nA few sentences could be made more concise. For example, “The challenge is not simply about technological supremacy” could be revised to “The challenge is not simply technological supremacy.” Similarly, “There is a strong push toward ‘Green AI,’ ensuring that...” could be phrased more directly as “Europe is also promoting ‘Green AI’ to ensure that...” The expression “massive salaries and computing resources offered by American and Chinese tech giants” is clear, but the overall paragraph would be more balanced with a specific example or a less absolute formulation. The use of quotation marks around terms such as “Green AI,” “trustworthy AI,” and “Brussels Effect” is acceptable, but these concepts should ideally be defined briefly when first introduced.\n\nOverall, the essay is polished, engaging, and grammatically strong. To reach an exceptional level, it should adopt a slightly more measured academic tone, reduce broad claims and decorative phrasing, and support major assertions with concrete evidence or examples.', score=9)

# %%
result.feedback
# Out:
# 'The essay demonstrates a high level of language quality. It is coherent, well organized, and written in a confident, professional style. The introduction establishes the central argument effectively, while the body paragraphs develop Europe’s strengths, ambitions, obstacles, and strategic choices in a logical sequence. The conclusion returns to the main theme and ends with a memorable contrast between Europe as a “global blueprint” and an “over-regulated museum.” Word choice is generally precise and sophisticated, with effective terms such as “regulatory muscle,” “compute deficit,” “brain drain,” and “Brussels Effect.” Sentence structure is varied, and transitions such as “Furthermore,” “Despite these noble ambitions,” “Consequently,” and “In conclusion” help maintain cohesion.\n\nThe main weakness is that the prose occasionally becomes overly rhetorical or generalized. Phrases such as “playing a unique and complex role,” “global conscience of the AI age,” “deep academic traditions,” and “fiercely protecting patient data” are persuasive but somewhat broad and would benefit from more precise qualification or supporting examples. Some metaphors—“rushes headlong,” “regulatory muscle,” and “over-regulated museum”—give the essay energy, but their frequent use slightly shifts the tone from analytical to editorial. The claim that the AI Act is the “world’s first comprehensive legal framework” may also require careful qualification, since the essay would be stronger if it distinguished between comprehensive regulation and earlier sector-specific or national AI rules.\n\nA few sentences could be made more concise. For example, “The challenge is not simply about technological supremacy” could be revised to “The challenge is not simply technological supremacy.” Similarly, “There is a strong push toward ‘Green AI,’ ensuring that...” could be phrased more directly as “Europe is also promoting ‘Green AI’ to ensure that...” The expression “massive salaries and computing resources offered by American and Chinese tech giants” is clear, but the overall paragraph would be more balanced with a specific example or a less absolute formulation. The use of quotation marks around terms such as “Green AI,” “trustworthy AI,” and “Brussels Effect” is acceptable, but these concepts should ideally be defined briefly when first introduced.\n\nOverall, the essay is polished, engaging, and grammatically strong. To reach an exceptional level, it should adopt a slightly more measured academic tone, reduce broad claims and decorative phrasing, and support major assertions with concrete evidence or examples.'

# %%
result.score
# Out:
# 9

# %%
class EssayState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: EssayState):
    prompt = (
        "Evaluate the language quality of the following essay and provide feedback "
        "and assign a score out of 10\n"
        f"{state['essay']}"
    )
    output = structured_model.invoke(prompt)
    return {
        "language_feedback": output.feedback,
        "individual_scores": [output.score],
    }

# %%
def evaluate_analysis(state: EssayState):
    prompt = (
        "Evaluate the depth of analysis of the following essay and provide feedback "
        "and assign a score out of 10\n"
        f"{state['essay']}"
    )
    output = structured_model.invoke(prompt)
    return {
        "analysis_feedback": output.feedback,
        "individual_scores": [output.score],
    }

# %%
def evaluate_thought(state: EssayState):
    prompt = (
        "Evaluate the clarity of thought of the following essay and provide feedback "
        "and assign a score out of 10\n"
        f"{state['essay']}"
    )
    output = structured_model.invoke(prompt)
    return {
        "clarity_feedback": output.feedback,
        "individual_scores": [output.score],
    }

# %%
def final_evaluation(state: EssayState):
    prompt = (
        "Based on the following feedbacks create a summarized feedback\n"
        f"language feedback - {state['language_feedback']}\n"
        f"depth of analysis feedback - {state['analysis_feedback']}\n"
        f"clarity of thought feedback - {state['clarity_feedback']}"
    )
    overall_feedback = structured_model.invoke(prompt)

    scores = state.get("individual_scores", [])
    avg_score = sum(scores) / len(scores) if scores else 0

    return {
        "overall_feedback": overall_feedback.feedback,
        "avg_score": avg_score,
    }

# %%
graph = StateGraph(EssayState)

graph.add_node("evaluate_analysis", evaluate_analysis)
graph.add_node("evaluate_language", evaluate_language)
graph.add_node("evaluate_thought", evaluate_thought)
graph.add_node("final_evaluation", final_evaluation)

graph.add_edge(START, "evaluate_analysis")
graph.add_edge(START, "evaluate_language")
graph.add_edge(START, "evaluate_thought")
graph.add_edge("evaluate_analysis", "final_evaluation")
graph.add_edge("evaluate_language", "final_evaluation")
graph.add_edge("evaluate_thought", "final_evaluation")
graph.add_edge("final_evaluation", END)

workflow = graph.compile()
workflow

# %%
initial_state = {
    "essay": essay,
}
result = workflow.invoke(initial_state)
result
# Out:
# {'essay': '"""Europe in the Age of AI: The Regulatory Superpower\n\nAs the world rushes headlong into the era of artificial intelligence, the European Union finds itself playing a unique and complex role. While the United States and China dominate the race to build the largest foundation models and hardware ecosystems, Europe has positioned itself as the global conscience of the AI age. For Europe, the challenge is not simply about technological supremacy, but about ensuring that AI aligns with democratic values, human rights, and environmental sustainability.\n\nEurope\'s strengths lie in its deep academic traditions and its commitment to ethical frameworks. The continent is home to world-class research hubs, producing some of the leading minds in machine learning. Furthermore, Europe has a distinct advantage in industrial and B2B AI, driven by its manufacturing powerhouses in Germany, France, and Scandinavia. However, Europe’s most defining characteristic in this era is its regulatory muscle. With the passage of the AI Act, the EU has created the world’s first comprehensive legal framework for artificial intelligence, categorizing systems by risk and demanding unprecedented transparency from tech companies.\n\nThe European vision for AI is heavily focused on public good and sustainability. There is a strong push toward "Green AI," ensuring that the massive energy consumption of data centers aligns with the continent\'s aggressive climate goals. In healthcare, European nations are leveraging AI to advance precision medicine and streamline public health systems, while fiercely protecting patient data. Additionally, significant investments are being made to develop open-source, multilingual AI models that preserve Europe\'s rich linguistic diversity and reduce reliance on Silicon Valley.\n\nDespite these noble ambitions, Europe faces substantial hurdles. The continent suffers from a severe lack of hyperscale tech companies and domestic cloud infrastructure, leaving it heavily dependent on foreign technology. This "compute deficit" is compounded by a fragmented venture capital market, which often struggles to commercialize academic breakthroughs. Consequently, Europe frequently experiences a brain drain, as its brightest AI researchers are lured away by the massive salaries and computing resources offered by American and Chinese tech giants.\n\nThe central tension for Europe is whether its regulatory approach will foster "trustworthy AI" or stifle homegrown innovation. Critics argue that stringent compliance burdens will price European startups out of the market, relegating the continent to being a consumer of foreign AI rather than a creator. Proponents, however, believe that by setting global ethical standards—the "Brussels Effect"—Europe will ultimately attract users and enterprises that demand secure, unbiased, and privacy-respecting technologies.\n\nTo succeed, Europe must balance its protective instincts with aggressive investment in digital infrastructure and innovation. It needs to foster a unified digital single market that allows startups to scale across borders effortlessly, while also forging strategic alliances to secure supply chains for critical hardware like semiconductors.\n\nIn conclusion, Europe in the age of AI represents a profound geopolitical experiment. It is testing whether a society can successfully govern exponential technology without sacrificing economic competitiveness. If Europe succeeds, it will provide a desperately needed global blueprint for human-centric AI; if it fails, it risks becoming an over-regulated museum in a world driven by algorithmic innovation."""',
#  'language_feedback': "The essay demonstrates very strong language quality. It is clear, fluent, well organized, and appropriately formal for an analytical opinion piece. The introduction establishes the central argument effectively, and the progression from Europe’s strengths to its challenges, tensions, and possible solutions is logical. Paragraphs are cohesive, with effective transitions such as “Furthermore,” “Despite these noble ambitions,” “Consequently,” and “To succeed.” The vocabulary is sophisticated and precise in places, particularly in phrases such as “regulatory muscle,” “compute deficit,” “fragmented venture capital market,” and “human-centric AI.” Sentence structure is varied, and the prose maintains a confident, engaging tone throughout. The use of parallelism in the conclusion—“if Europe succeeds...; if it fails...” —is especially effective.\n\nA few expressions are somewhat clichéd or rhetorically exaggerated, including “rushes headlong,” “global conscience,” “massive salaries,” and “an over-regulated museum.” These phrases are vivid, but a more neutral academic style could make the argument sound more measured. “The leading minds in machine learning” is also broad and slightly imprecise, while “fiercely protecting patient data” is more emotive than analytical. The essay could benefit from occasional qualification, especially when making sweeping claims about Europe, the United States, China, or the AI Act. In addition, “industrial and B2B AI” is understandable but slightly compressed; “industrial and business-to-business applications of AI” would be more polished. The phrase “the world's first comprehensive legal framework” may require careful qualification if the essay is intended as factual analysis, though this is primarily a content issue rather than a language error.\n\nOverall, the essay is highly polished, coherent, and persuasive, with only minor opportunities to reduce hyperbole and increase precision. It reads close to professional editorial or policy writing.",
#  'analysis_feedback': 'The essay offers a clear, coherent, and reasonably sophisticated overview of Europe’s position in the global AI landscape. Its strongest analytical feature is the identification of a central tension: Europe seeks to lead through regulation and ethical governance while remaining competitive with the United States and China. The discussion of the “Brussels Effect,” the EU AI Act, data protection, sustainability, industrial AI, and Europe’s dependence on foreign cloud and computing infrastructure demonstrates good awareness of the major strategic issues. The essay also recognizes that regulation alone cannot produce technological power and appropriately links AI competitiveness to venture capital, talent retention, infrastructure, semiconductors, and the digital single market.\n\nHowever, the depth of analysis is limited by the essay’s largely general and declarative style. Many claims are plausible but are not supported with concrete evidence, examples, statistics, or specific comparisons. For instance, the essay refers to Europe’s “severe lack of hyperscale tech companies,” its “compute deficit,” brain drain, and fragmented venture capital market, but does not explain their scale or show how they directly affect European firms. Similarly, the AI Act is described as comprehensive and demanding “unprecedented transparency,” but the essay does not distinguish between the Act’s risk categories, obligations for general-purpose AI, implementation challenges, or the uncertainty surrounding enforcement. More precise treatment would make the argument more credible.\n\nThe essay also sometimes relies on broad generalizations. Europe is presented as a unified actor, although EU member states differ substantially in industrial capacity, investment levels, regulatory preferences, and AI capabilities. Germany’s manufacturing strengths, France’s state-supported AI strategy, the Nordic countries’ digitalization, and smaller states’ approaches could have been contrasted to show this complexity. The comparison with the United States and China is also somewhat simplified: the United States is treated mainly as a technology leader and China as a competing hardware and model powerhouse, without discussing their different regulatory systems, state-industry relationships, or weaknesses.\n\nThe argument about regulation is balanced in outline but not fully developed. The essay presents both the innovation-stifling and trust-enhancing perspectives, yet it does not assess the conditions under which either outcome is more likely. It could ask whether compliance costs affect startups and large firms differently, whether regulation creates barriers to entry or advantages for established companies, and whether global companies will actually adapt worldwide to EU rules or instead limit access to European markets. The “Brussels Effect” is invoked rather than demonstrated through a concrete example. Likewise, the discussion of Green AI would be stronger if it addressed the trade-off between energy-intensive model development, efficiency gains, transparency requirements, and the environmental cost of regulation itself.\n\nThe recommendations are sensible but broad. Calls for infrastructure investment, a unified digital market, and supply-chain alliances would benefit from prioritization and explanation. The essay could distinguish between policies Europe can implement independently and those requiring cooperation with the United States or other partners. It could also consider the political and financial obstacles to these measures.\n\nOverall, this is a well-organized and informed essay with a strong thesis and good breadth, but it functions more as a strategic overview than as a deeply evidenced analysis. Greater specificity, empirical support, engagement with opposing arguments, and attention to differences within Europe would substantially improve it.',
#  'clarity_feedback': 'The essay presents a clear and coherent central argument: Europe is unlikely to lead the AI race through scale or hardware, but can exert influence through regulation, ethical standards, sustainability, and industrial applications. Its structure is logical, moving from Europe’s distinctive role and strengths, to its ambitions, challenges, central regulatory tension, proposed solutions, and final implications. The contrast between the United States and China and Europe’s role as a “regulatory superpower” gives the discussion a consistent organizing idea. Transitions are generally smooth, and the essay maintains focus throughout. The use of concepts such as the “Brussels Effect,” “Green AI,” and the “compute deficit” also helps frame the argument effectively.\n\nThe clarity of thought would improve with greater precision and deeper explanation in several places. Some claims are broad or slightly overstated, such as describing Europe as the “global conscience” of AI, calling the AI Act the world’s first “comprehensive” framework, or suggesting that Europe is “fiercely protecting” patient data. These phrases are rhetorically strong but would benefit from qualification, evidence, or concrete examples. The essay sometimes moves quickly from one topic to another—research, industrial AI, regulation, healthcare, sustainability, open-source models, venture capital, and brain drain—without fully explaining how each supports the main argument. The proposed solutions are sensible but underdeveloped: for example, the essay could specify how Europe might unify its digital market, improve access to compute, or balance compliance costs for startups.\n\nThe conclusion is memorable and effectively restates the stakes, although the phrase “over-regulated museum” is somewhat dramatic and presents the outcome as more binary than the preceding analysis suggests. Overall, the essay is very readable and well organized, with a strong conceptual framework. Its main weakness is not confusion but limited nuance and supporting detail. Adding evidence, acknowledging differences among EU member states, and distinguishing between regulation that protects users and regulation that creates unnecessary burdens would make the reasoning more rigorous.',
#  'overall_feedback': 'The essay is highly polished, clear, and well organized, with a strong central argument and logical progression. It effectively presents Europe’s distinctive potential to influence AI through regulation, ethics, sustainability, and industrial applications, while also acknowledging its weaknesses in computing infrastructure, venture capital, talent retention, semiconductors, and digital-market integration. The discussion of concepts such as the Brussels Effect, the EU AI Act, Green AI, and the compute deficit gives the essay a coherent analytical framework. Vocabulary is sophisticated, sentence structure is varied, and transitions are effective, creating a confident and appropriately formal tone.\n\nThe main limitation is that the essay provides a broad strategic overview rather than a deeply evidenced analysis. Many claims about Europe’s technological disadvantages, the effects of regulation, and comparisons with the United States and China are plausible but general. The argument would be stronger with statistics, concrete examples, clearer explanations of the AI Act’s specific obligations, and evidence demonstrating the Brussels Effect. It should also acknowledge differences among EU member states, since Europe is not a completely unified actor in terms of investment, industrial strength, policy, or AI capability. The comparison with the United States and China could likewise be more nuanced.\n\nThe essay’s treatment of regulation is balanced in principle but would benefit from examining when regulation supports trust and innovation and when it creates compliance burdens, particularly for startups. The proposed solutions—greater infrastructure investment, a unified digital market, stronger supply chains, and improved talent retention—are sensible but broad; they need prioritization, practical detail, and discussion of political and financial obstacles. Some sections also move quickly between topics without fully showing how each relates to the main thesis.\n\nStylistically, the essay is close to professional policy or editorial writing, though a few expressions are exaggerated or clichéd, such as “global conscience,” “rushes headlong,” “massive salaries,” and “an over-regulated museum.” Replacing these with more measured language and qualifying sweeping claims would improve precision and academic credibility. Overall, the essay is persuasive, coherent, and sophisticated, but it would become substantially stronger through greater specificity, empirical support, deeper engagement with counterarguments, and more nuanced treatment of Europe’s internal diversity and regulatory challenges.',
#  'individual_scores': [7, 9, 8],
#  'avg_score': 8.0}
